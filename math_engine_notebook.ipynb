# %% [markdown]
# # 🧮 Math Calculation Engine - Interactive Notebook
#
# Welcome to the Math Calculation Engine! This notebook provides an interactive environment for exploring mathematical calculations using our modular engine.
#
# ## Features
# - ✅ Strict argument validation
# - ✅ Extensible operation system
# - ✅ Comprehensive error handling
# - ✅ Multiple operation categories
#
# Let's start by importing the engine components:

# %%
# Import the Math Calculation Engine
from core import calculate, Operation, list_operations, get_operation_info

print("🚀 Math Calculation Engine loaded successfully!")
print(f"📊 Available operations: {len(list_operations())}")
# Out:
# 🚀 Math Calculation Engine loaded successfully!
# 📊 Available operations: 108

# %% [markdown]
# ## 📋 Available Operations
#
# Let's explore what operations are available:

# %%
# List all available operations
operations = list_operations()

print("Available Operations:")
print("=" * 50)

for op_info in operations:
    print(f"🔹 {op_info['operation'].name}")
    print(f"   Required args: {', '.join(op_info['required_args'])}")
    if op_info['docstring']:
        print(f"   Description: {op_info['docstring'].strip()}")
    print()
# Out:
# Available Operations:
# ==================================================
# 🔹 ADD
#    Required args: a, b
#    Description: Add two numbers.
#
# 🔹 SUBTRACT
#    Required args: a, b
#    Description: Subtract b from a.
#
# 🔹 MULTIPLY
#    Required args: a, b
#    Description: Multiply two numbers.
#
# 🔹 DIVIDE
#    Required args: a, b
#    Description: Divide a by b.
#
# 🔹 MODULO
#    Required args: a, b
#    Description: Calculate a modulo b (remainder of a/b).
#
# 🔹 FLOOR_DIVIDE
#    Required args: a, b
#    Description: Floor division (integer division).
#
# 🔹 POWER
#    Required args: num, power
#    Description: Raise num to the given power.
#
# 🔹 SQUARE_ROOT
#    Required args: num
#    Description: Calculate the square root of a number.
#
# 🔹 CUBE_ROOT
#    Required args: num
#    Description: Calculate the cube root of a number.
#
# 🔹 NTH_ROOT
#    Required args: num, n
#    Description: Calculate the nth root of a number.
#
# 🔹 SQUARE
#    Required args: num
#    Description: Calculate the square of a number.
#
# 🔹 CUBE
#    Required args: num
#    Description: Calculate the cube of a number.
#
# 🔹 ABSOLUTE_VALUE
#    Required args: num
#    Description: Calculate the absolute value of a number.
#
# 🔹 SIGN
#    Required args: num
#    Description: Return the sign of a number (-1, 0, or 1).
#
# 🔹 CEILING
#    Required args: num
#    Description: Round up to the nearest integer.
#
# 🔹 FLOOR
#    Required args: num
#    Description: Round down to the nearest integer.
#
# 🔹 ROUND_TO_DECIMALS
#    Required args: num, decimals
#    Description: Round to specified number of decimal places.
#
# 🔹 FACTORIAL
#    Required args: n
#    Description: Calculate factorial of n.
#
# 🔹 COMBINATION
#    Required args: n, r
#    Description: Calculate combination C(n,r) = n! / (r! * (n-r)!).
#
# 🔹 PERMUTATION
#    Required args: n, r
#    Description: Calculate permutation P(n,r) = n! / (n-r)!.
#
# 🔹 GCD
#    Required args: a, b
#    Description: Calculate the greatest common divisor using Euclidean algorithm.
#
# 🔹 LCM
#    Required args: a, b
#    Description: Calculate the least common multiple.
#
# 🔹 IS_PRIME
#    Required args: n
#    Description: Check if a number is prime.
#
# 🔹 FIBONACCI
#    Required args: n
#    Description: Calculate the nth Fibonacci number.
#
# 🔹 ARITHMETIC_MEAN
#    Required args: a, b
#    Description: Calculate arithmetic mean of two numbers.
#
# 🔹 GEOMETRIC_MEAN
#    Required args: a, b
#    Description: Calculate geometric mean of two numbers.
#
# 🔹 HARMONIC_MEAN
#    Required args: a, b
#    Description: Calculate harmonic mean of two numbers.
#
# 🔹 PERCENTAGE
#    Required args: part, whole
#    Description: Calculate what percentage 'part' is of 'whole'.
#
# 🔹 PERCENTAGE_CHANGE
#    Required args: old_value, new_value
#    Description: Calculate percentage change from old value to new value.
#
# 🔹 AREA_CIRCLE
#    Required args: radius
#    Description: Calculate the area of a circle given its radius.
#
# 🔹 AREA_RECTANGLE
#    Required args: length, width
#    Description: Calculate the area of a rectangle.
#
# 🔹 AREA_SQUARE
#    Required args: side
#    Description: Calculate the area of a square.
#
# 🔹 AREA_TRIANGLE
#    Required args: base, height
#    Description: Calculate the area of a triangle using base and height.
#
# 🔹 AREA_TRIANGLE_HERON
#    Required args: a, b, c
#    Description: Calculate the area of a triangle using Heron's formula.
#
# 🔹 AREA_RHOMBUS
#    Required args: diagonal1, diagonal2
#    Description: Calculate the area of a rhombus using diagonals.
#
# 🔹 AREA_TRAPEZOID
#    Required args: base1, base2, height
#    Description: Calculate the area of a trapezoid.
#
# 🔹 AREA_REGULAR_POLYGON
#    Required args: perimeter, apothem
#    Description: Calculate the area of a regular polygon.
#
# 🔹 AREA_ELLIPSE
#    Required args: semi_major_axis, semi_minor_axis
#    Description: Calculate the area of an ellipse.
#
# 🔹 AREA_SECTOR
#    Required args: radius, angle_degrees
#    Description: Calculate the area of a circular sector.
#
# 🔹 AREA_ANNULUS
#    Required args: outer_radius, inner_radius
#    Description: Calculate the area of an annulus (ring).
#
# 🔹 CIRCUMFERENCE_CIRCLE
#    Required args: radius
#    Description: Calculate the circumference of a circle.
#
# 🔹 PERIMETER_RECTANGLE
#    Required args: length, width
#    Description: Calculate the perimeter of a rectangle.
#
# 🔹 PERIMETER_SQUARE
#    Required args: side
#    Description: Calculate the perimeter of a square.
#
# 🔹 PERIMETER_TRIANGLE
#    Required args: a, b, c
#    Description: Calculate the perimeter of a triangle.
#
# 🔹 PERIMETER_REGULAR_POLYGON
#    Required args: num_sides, side_length
#    Description: Calculate the perimeter of a regular polygon.
#
# 🔹 PERIMETER_ELLIPSE
#    Required args: semi_major_axis, semi_minor_axis
#    Description: Calculate approximate perimeter of an ellipse using Ramanujan's approximation.
#
# 🔹 DISTANCE_2D
#    Required args: x1, y1, x2, y2
#    Description: Calculate distance between two points in 2D space.
#
# 🔹 DISTANCE_3D
#    Required args: x1, y1, z1, x2, y2, z2
#    Description: Calculate distance between two points in 3D space.
#
# 🔹 MIDPOINT_2D
#    Required args: x1, y1, x2, y2
#    Description: Calculate midpoint between two points in 2D space.
#
# 🔹 SLOPE_LINE
#    Required args: x1, y1, x2, y2
#    Description: Calculate the slope of a line between two points.
#
# 🔹 ANGLE_BETWEEN_VECTORS
#    Required args: x1, y1, x2, y2
#    Description: Calculate angle between two vectors in degrees.
#
# 🔹 VOLUME_CUBE
#    Required args: side
#    Description: Calculate the volume of a cube.
#
# 🔹 VOLUME_RECTANGULAR_PRISM
#    Required args: length, width, height
#    Description: Calculate the volume of a rectangular prism (box).
#
# 🔹 VOLUME_SPHERE
#    Required args: radius
#    Description: Calculate the volume of a sphere.
#
# 🔹 VOLUME_CYLINDER
#    Required args: radius, height
#    Description: Calculate the volume of a cylinder.
#
# 🔹 VOLUME_CONE
#    Required args: radius, height
#    Description: Calculate the volume of a cone.
#
# 🔹 VOLUME_PYRAMID
#    Required args: base_area, height
#    Description: Calculate the volume of a pyramid.
#
# 🔹 VOLUME_ELLIPSOID
#    Required args: a, b, c
#    Description: Calculate the volume of an ellipsoid.
#
# 🔹 SURFACE_AREA_SPHERE
#    Required args: radius
#    Description: Calculate the surface area of a sphere.
#
# 🔹 SURFACE_AREA_CYLINDER
#    Required args: radius, height
#    Description: Calculate the surface area of a cylinder.
#
# 🔹 SURFACE_AREA_CONE
#    Required args: radius, slant_height
#    Description: Calculate the surface area of a cone.
#
# 🔹 SIN_DEGREES
#    Required args: angle_degrees
#    Description: Calculate sine of angle in degrees.
#
# 🔹 COS_DEGREES
#    Required args: angle_degrees
#    Description: Calculate cosine of angle in degrees.
#
# 🔹 TAN_DEGREES
#    Required args: angle_degrees
#    Description: Calculate tangent of angle in degrees.
#
# 🔹 SIN_RADIANS
#    Required args: angle_radians
#    Description: Calculate sine of angle in radians.
#
# 🔹 COS_RADIANS
#    Required args: angle_radians
#    Description: Calculate cosine of angle in radians.
#
# 🔹 TAN_RADIANS
#    Required args: angle_radians
#    Description: Calculate tangent of angle in radians.
#
# 🔹 ASIN_DEGREES
#    Required args: value
#    Description: Calculate arcsine in degrees.
#
# 🔹 ACOS_DEGREES
#    Required args: value
#    Description: Calculate arccosine in degrees.
#
# 🔹 ATAN_DEGREES
#    Required args: value
#    Description: Calculate arctangent in degrees.
#
# 🔹 ASIN_RADIANS
#    Required args: value
#    Description: Calculate arcsine in radians.
#
# 🔹 ACOS_RADIANS
#    Required args: value
#    Description: Calculate arccosine in radians.
#
# 🔹 ATAN_RADIANS
#    Required args: value
#    Description: Calculate arctangent in radians.
#
# 🔹 ATAN2_DEGREES
#    Required args: y, x
#    Description: Calculate two-argument arctangent in degrees.
#
# 🔹 ATAN2_RADIANS
#    Required args: y, x
#    Description: Calculate two-argument arctangent in radians.
#
# 🔹 SEC_DEGREES
#    Required args: angle_degrees
#    Description: Calculate secant of angle in degrees.
#
# 🔹 CSC_DEGREES
#    Required args: angle_degrees
#    Description: Calculate cosecant of angle in degrees.
#
# 🔹 COT_DEGREES
#    Required args: angle_degrees
#    Description: Calculate cotangent of angle in degrees.
#
# 🔹 DEGREES_TO_RADIANS
#    Required args: degrees
#    Description: Convert degrees to radians.
#
# 🔹 RADIANS_TO_DEGREES
#    Required args: radians
#    Description: Convert radians to degrees.
#
# 🔹 NATURAL_LOG
#    Required args: x
#    Description: Calculate natural logarithm (base e).
#
# 🔹 LOG_BASE_10
#    Required args: x
#    Description: Calculate logarithm base 10.
#
# 🔹 LOG_BASE_2
#    Required args: x
#    Description: Calculate logarithm base 2.
#
# 🔹 LOG_CUSTOM_BASE
#    Required args: x, base
#    Description: Calculate logarithm with custom base.
#
# 🔹 EXPONENTIAL_E
#    Required args: x
#    Description: Calculate e raised to the power x.
#
# 🔹 EXPONENTIAL_BASE_10
#    Required args: x
#    Description: Calculate 10 raised to the power x.
#
# 🔹 EXPONENTIAL_BASE_2
#    Required args: x
#    Description: Calculate 2 raised to the power x.
#
# 🔹 EXPONENTIAL_CUSTOM_BASE
#    Required args: base, exponent
#    Description: Calculate base raised to the given exponent.
#
# 🔹 SINH
#    Required args: x
#    Description: Calculate hyperbolic sine.
#
# 🔹 COSH
#    Required args: x
#    Description: Calculate hyperbolic cosine.
#
# 🔹 TANH
#    Required args: x
#    Description: Calculate hyperbolic tangent.
#
# 🔹 ASINH
#    Required args: x
#    Description: Calculate inverse hyperbolic sine.
#
# 🔹 ACOSH
#    Required args: x
#    Description: Calculate inverse hyperbolic cosine.
#
# 🔹 ATANH
#    Required args: x
#    Description: Calculate inverse hyperbolic tangent.
#
# 🔹 MEAN
#    Required args: values
#    Description: Calculate arithmetic mean (average).
#
# 🔹 MEDIAN
#    Required args: values
#    Description: Calculate median (middle value).
#
# 🔹 MODE
#    Required args: values
#    Description: Calculate mode (most frequent value).
#
# 🔹 VARIANCE_POPULATION
#    Required args: values
#    Description: Calculate population variance.
#
# 🔹 VARIANCE_SAMPLE
#    Required args: values
#    Description: Calculate sample variance.
#
# 🔹 STANDARD_DEVIATION_POPULATION
#    Required args: values
#    Description: Calculate population standard deviation.
#
# 🔹 STANDARD_DEVIATION_SAMPLE
#    Required args: values
#    Description: Calculate sample standard deviation.
#
# 🔹 RANGE_VALUES
#    Required args: values
#    Description: Calculate range (max - min).
#
# 🔹 QUARTILE_1
#    Required args: values
#    Description: Calculate first quartile (Q1).
#
# 🔹 QUARTILE_3
#    Required args: values
#    Description: Calculate third quartile (Q3).
#
# 🔹 INTERQUARTILE_RANGE
#    Required args: values
#    Description: Calculate interquartile range (Q3 - Q1).
#
# 🔹 CORRELATION_COEFFICIENT
#    Required args: x_values, y_values
#    Description: Calculate Pearson correlation coefficient.
#
# 🔹 Z_SCORE
#    Required args: value, population_mean, population_std
#    Description: Calculate z-score (standard score).
#
# 🔹 PERCENTILE
#    Required args: values, percentile_rank
#    Description: Calculate the value at a given percentile.

# %% [markdown]
# ## 🔢 Basic Arithmetic Operations
#
# Let's start with some basic arithmetic:

# %%
# Addition
result = calculate(operation=Operation.ADD, a=15, b=27)
print(f"15 + 27 = {result}")

# Subtraction
result = calculate(operation=Operation.SUBTRACT, a=100, b=42)
print(f"100 - 42 = {result}")

# Multiplication
result = calculate(operation=Operation.MULTIPLY, a=7, b=8)
print(f"7 × 8 = {result}")

# Division
result = calculate(operation=Operation.DIVIDE, a=144, b=12)
print(f"144 ÷ 12 = {result}")
# Out:
# 15 + 27 = 42
# 100 - 42 = 58
# 7 × 8 = 56
# 144 ÷ 12 = 12.0

# %% [markdown]
# ## ⚡ Power and Root Operations

# %%
# Power calculations
result = calculate(operation=Operation.POWER, num=2, power=10)
print(f"2^10 = {result}")

result = calculate(operation=Operation.POWER, num=5, power=3)
print(f"5^3 = {result}")

# Square root
result = calculate(operation=Operation.SQUARE_ROOT, num=64)
print(f"√64 = {result}")

result = calculate(operation=Operation.SQUARE_ROOT, num=100)
print(f"√100 = {result}")
# Out:
# 2^10 = 1024
# 5^3 = 125
# √64 = 8.0
# √100 = 10.0

# %% [markdown]
# ## 📐 Geometry Operations
#
# Now let's work with geometric shapes:

# %%
import math

# Circle calculations
radius = 5
area = calculate(operation=Operation.AREA_CIRCLE, radius=radius)
circumference = calculate(operation=Operation.CIRCUMFERENCE_CIRCLE, radius=radius)

print(f"Circle with radius {radius}:")
print(f"  Area: {area:.2f}")
print(f"  Circumference: {circumference:.2f}")
print(f"  Expected area: {math.pi * radius**2:.2f}")
# Out:
# Circle with radius 5:
#   Area: 78.54
#   Circumference: 31.42
#   Expected area: 78.54

# %%
# Rectangle calculations
length, width = 12, 8
area = calculate(operation=Operation.AREA_RECTANGLE, length=length, width=width)
perimeter = calculate(operation=Operation.PERIMETER_RECTANGLE, length=length, width=width)

print(f"Rectangle {length} × {width}:")
print(f"  Area: {area}")
print(f"  Perimeter: {perimeter}")
# Out:
# Rectangle 12 × 8:
#   Area: 96
#   Perimeter: 40

# %%
# Triangle calculations
base, height = 10, 6
area = calculate(operation=Operation.AREA_TRIANGLE, base=base, height=height)

print(f"Triangle with base {base} and height {height}:")
print(f"  Area: {area}")
# Out:
# Triangle with base 10 and height 6:
#   Area: 30.0

# %% [markdown]
# ## ⚠️ Error Handling Examples
#
# The engine provides strict validation. Let's see how it handles errors:

# %%
# Example 1: Missing required argument
try:
    result = calculate(operation=Operation.ADD, a=5)  # Missing 'b'
except ValueError as e:
    print(f"❌ Missing argument error: {e}")

# Example 2: Unexpected argument
try:
    result = calculate(operation=Operation.ADD, a=5, b=3, c=1)  # 'c' not expected
except ValueError as e:
    print(f"❌ Unexpected argument error: {e}")

# Example 3: Division by zero
try:
    result = calculate(operation=Operation.DIVIDE, a=10, b=0)
except ValueError as e:
    print(f"❌ Division by zero error: {e}")
# Out:
# ❌ Missing argument error: Missing required arguments: b
# ❌ Unexpected argument error: Unexpected arguments: c
# ❌ Division by zero error: Calculation error: Division by zero is not allowed

# %% [markdown]
# ## 🧪 Interactive Calculation Playground
#
# Use this cell to try your own calculations:

# %%
# Try your own calculations here!
# Examples:
# calculate(operation=Operation.POWER, num=3, power=4)
# calculate(operation=Operation.AREA_CIRCLE, radius=7.5)
# calculate(operation=Operation.MULTIPLY, a=12, b=15)

# Your code here:

print(calculate(operation=Operation.DIVIDE, a=120, b=15))
# Out:
# 8.0

# %% [markdown]
# ## 📊 Operation Information Helper
#
# Get detailed information about any operation:

# %%
# Get info about a specific operation
operation = Operation.AREA_CIRCLE  # Change this to explore other operations
info = get_operation_info(operation)

if info:
    print(f"Operation: {info['operation'].name}")
    print(f"Function: {info['function_name']}")
    print(f"Required arguments: {', '.join(info['required_args'])}")
    print(f"Description: {info['docstring']}")
else:
    print("Operation not found")
# Out:
# Operation: AREA_CIRCLE
# Function: area_circle
# Required arguments: radius
# Description: Calculate the area of a circle given its radius.

# %% [markdown]
# ## 🎯 Complex Calculation Examples
#
# Let's combine multiple operations for more complex calculations:

# %%
# Calculate the area of a circular garden and surrounding walkway
garden_radius = 5
walkway_width = 2
total_radius = garden_radius + walkway_width

garden_area = calculate(operation=Operation.AREA_CIRCLE, radius=garden_radius)
total_area = calculate(operation=Operation.AREA_CIRCLE, radius=total_radius)
walkway_area = calculate(operation=Operation.SUBTRACT, a=total_area, b=garden_area)

print(f"Garden Design Calculation:")
print(f"  Garden radius: {garden_radius}m")
print(f"  Walkway width: {walkway_width}m")
print(f"  Garden area: {garden_area:.2f} m²")
print(f"  Walkway area: {walkway_area:.2f} m²")
print(f"  Total area: {total_area:.2f} m²")
# Out:
# Garden Design Calculation:
#   Garden radius: 5m
#   Walkway width: 2m
#   Garden area: 78.54 m²
#   Walkway area: 75.40 m²
#   Total area: 153.94 m²

# %%
# Calculate compound interest using power function
principal = 1000  # Initial amount
rate = 1.05       # 5% annual interest (1 + 0.05)
years = 10

# A = P(1 + r)^t
amount = calculate(operation=Operation.MULTIPLY, 
                  a=principal, 
                  b=calculate(operation=Operation.POWER, num=rate, power=years))

interest_earned = calculate(operation=Operation.SUBTRACT, a=amount, b=principal)

print(f"Compound Interest Calculation:")
print(f"  Principal: ${principal:,.2f}")
print(f"  Annual rate: 5%")
print(f"  Years: {years}")
print(f"  Final amount: ${amount:,.2f}")
print(f"  Interest earned: ${interest_earned:,.2f}")
# Out:
# Compound Interest Calculation:
#   Principal: $1,000.00
#   Annual rate: 5%
#   Years: 10
#   Final amount: $1,628.89
#   Interest earned: $628.89

# %% [markdown]
# ## 🎉 Congratulations!
#
# You've successfully explored the Math Calculation Engine!
#
# ### Next Steps:
# - Try the CLI version: `python calc.py --interactive`
# - Explore the source code in the `core/` directory
# - Add your own operations by extending the formulas modules
# - Use the engine in your own Python projects
#
# ### Key Features Demonstrated:
# ✅ Strict argument validation
# ✅ Multiple operation categories
# ✅ Comprehensive error handling
# ✅ Easy extensibility
# ✅ Both programmatic and interactive use
#
# Happy calculating! 🧮
